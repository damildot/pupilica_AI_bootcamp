# %% [markdown]
# <a href="https://colab.research.google.com/github/damildot/pupilica_AI_bootcamp/blob/main/matplotlib-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **histogram**

# %%
import pandas as pd
import numpy as np
veri=pd.read_csv("iris.csv")
veri
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# *bins=20 olarak ayarlanmış. Bu, "PetalLengthCm" verilerinin 20 aralığa bölüneceği ve histogramın 20 çubuktan oluşacağı anlamına gelir.*

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(veri["SepalLengthCm"], color = "red", alpha = 0.9, bins=20 , label = "SepalLengthCm")
plt.hist(veri["PetalLengthCm"], color = "blue", alpha = 0.9, bins=20 , label = "PetalLengthCm")

plt.ylabel("Frekans (Kaç adet olduğu)")
plt.xlabel("cm")
plt.legend()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Subplots: Alt plan grafiği**
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
veri = pd.read_csv("iris.csv")
veri
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots(2,1) # 2 satir, 1 sutun
fig.suptitle("Ana baslik")
ax[0].plot(veri.SepalLengthCm, color = "red") # ax'lerin sifirincisi ilk eksen birinci plot
ax[0].set_title("Sepal Length")
ax[0].set_xlabel("index")
ax[0].set_ylabel("cm")

ax[1].plot(veri.PetalLengthCm, color = "blue")
ax[1].set_title("Petal Length")
ax[1].set_xlabel("index")
ax[1].set_ylabel("cm")

fig.tight_layout() # matplotlib kütüphanesinde alt grafikler arasındaki boşlukları otomatik olarak ayarlar.
fig.subplots_adjust(top = 0.85)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

# 2x2'lik bir grid içinde 4 alt grafik oluştur
plt.subplot(2, 2, 1) # 2 satir ve 2 sutundan olussun ve ben 1. plotu cizdiriyorum
plt.scatter([1, 2, 3, 4], [5, 6, 7, 8])
plt.title("Alt Grafik 1")

plt.subplot(2, 2, 2)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 2")

plt.subplot(2, 2, 3) # 2 satir ve 2 sutundan olussun ve ben 3. plotu cizdiriyorum
plt.hist([1, 2, 3, 4, 5, 6, 7, 8])
plt.title("Alt Grafik 3")

plt.subplot(2, 2, 4)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 4")

plt.show() # Grafikleri göster

# %% [markdown]
# **alıştırma**

# %%
# dataseti indir: https://github.com/prashant-kikani/breast-cancer-detection/blob/master/breast-cancer-data.csv
# class'larin (target variable) diagnosis ayrilmasi
# 2,3 bir subplot cizdirelim
# ilk satirda     M için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
# ikinici satirda B için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)

# %%
import pandas as pd
data = pd.read_csv("breast-cancer-data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
# class'larin (target variable) diagnosis ayrilmasi
m = data[data["diagnosis"] == "M"]
m.reset_index(drop=True, inplace=True)
b = data[data["diagnosis"] == "B"]
b.reset_index(drop=True, inplace=True)

# ilk satirda     M için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
plt.subplot(2, 3, 1)
plt.scatter(m.radius_mean, m.texture_mean)

plt.subplot(2, 3, 2)
plt.hist(m.radius_mean)

plt.subplot(2, 3, 3)
plt.plot(m.radius_mean)

# ikinici satirda B için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
plt.subplot(2, 3, 4)
plt.scatter(b.radius_mean, b.texture_mean)

plt.subplot(2, 3, 5)
plt.hist(b.radius_mean)

plt.subplot(2, 3, 6)
plt.plot(b.radius_mean)
