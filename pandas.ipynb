# %% [markdown]
# <a href="https://colab.research.google.com/github/damildot/pupilica_AI_bootcamp/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **pandas** : verinin training için hazır hale getirilmesi
# EDA keşfisel veri analizi :outlier tespiti,feature extraction,correlation
#
#
# ---
#
#
# *Pandas veriyi
# okuma, düzenleme, analiz etme ve dönüştürme için kullanılır. DataFrame
# yapısıyla tablosal veriler üzerinde kolayca işlem yapılabilir. Veri filtreleme,
# eksik verileri doldurma ve gruplama gibi işlemler birkaç satır kod ile
# gerçekleştirilir. Pandas, farklı formatlardaki (CSV, Excel, SQL) verileri hızlıca
# okur ve işler. Ayrıca, zaman serisi analizi gibi özelliklerle zaman bazlı veriler
# üzerinde esnek çalışmalar yapılmasını sağlar.Özetle, NumPy hızlı sayısal
# hesaplamalar için, Pandas ise veriyi analiz edip anlamlı hale getirmek için
# kullanılır.*

# %% [markdown]
# **pandas**; *iki temel veri yapısına dayanır: Series ve DataFrame.*
#
#
# ---
#
#
# *Series:Tek boyutlu, etiketlenmiş bir dizidir.*
#
# ```
# import pandas as pd
# series = pd.Series([1, 3, 5, 7], index=['a', 'b', 'c', 'd'])
# print(series)
# ```
#
# *DataFrame:İki boyutlu, tablo benzeri bir veri yapısıdır.*
#
# ```
# data = {'Name': ['Ali', 'Ayşe', 'Ahmet'], 'Age': [25, 30, 35]}
# df = pd.DataFrame(data)
# print(df)
# ```

# %%
import pandas as pd
import numpy as np

# %%
dictionary={"isim":["damla","arda","rukiye","pari","abdullah"],
            "yas":[24,32,27,np.nan,45],
            "maas":[1000.0,2000.0,3000.0,4000.0,5000.0]}

# %%
veri=pd.DataFrame(dictionary)

# %%
print(veri.head()) #ilk beş satır
print("-------------------------------")
print(veri.tail()) #son 5 satır
print("-------------------------------")
print(veri.info()) #dataframe ile ilgili temel bilgilere erişmemiz lazım
print("-------------------------------")
print(veri.dtypes) # display the data types of each column in the Pandas DataFrame
print("-------------------------------")
print(veri.columns) #verinin sütunları
print("-------------------------------")
print(veri.axes)
print("-------------------------------")
print(veri.describe()) # veri seti icerisinde bulunan numeric feature'larin temel istatistiksel analizi
# Out:
#        isim   yas    maas
# 0     damla  24.0  1000.0
# 1      arda  32.0  2000.0
# 2    rukiye  27.0  3000.0
# 3      pari   NaN  4000.0
# 4  abdullah  45.0  5000.0
# -------------------------------
#        isim   yas    maas
# 0     damla  24.0  1000.0
# 1      arda  32.0  2000.0
# 2    rukiye  27.0  3000.0
# 3      pari   NaN  4000.0
# 4  abdullah  45.0  5000.0
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    5 non-null      object
#  1   yas     4 non-null      float64
#  2   maas    5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 248.0+ bytes
# None
# -------------------------------
# isim     object
# yas     float64
# maas    float64
# dtype: object
# -------------------------------
# Index(['isim', 'yas', 'maas'], dtype='object')
# -------------------------------
# ...

# %% [markdown]
# **indeksleme ve dilimleme**

# %%
dictionary={"isim":["damla","arda","rukiye","pari","abdullah"],
            "yas":[24,32,27,np.nan,45],
            "maas":[1000.0,2000.0,3000.0,4000.0,5000.0]}
veri=pd.DataFrame(dictionary)

# %%
veri
# Out:
#        isim   yas    maas
# 0     damla  24.0  1000.0
# 1      arda  32.0  2000.0
# 2    rukiye  27.0  3000.0
# 3      pari   NaN  4000.0
# 4  abdullah  45.0  5000.0

# %%
print(veri["yas"])
print("-------------------------------")
print(veri[["isim","maas"]])
print("-------------------------------")
# Out:
# 0    24.0
# 1    32.0
# 2    27.0
# 3     NaN
# 4    45.0
# Name: yas, dtype: float64
# -------------------------------
#        isim    maas
# 0     damla  1000.0
# 1      arda  2000.0
# 2    rukiye  3000.0
# 3      pari  4000.0
# 4  abdullah  5000.0
# -------------------------------

# %%
#dataFrame içerisinde yeni sütun ekleme
veri["sehir"]="istanbul"
veri["ilce"]=["kuzguncuk",np.nan,"gebze","kaynarca","pendik"]
veri
# Out:
#        isim   yas    maas     sehir       ilce
# 0     damla  24.0  1000.0  istanbul  kuzguncuk
# 1      arda  32.0  2000.0  istanbul        NaN
# 2    rukiye  27.0  3000.0  istanbul      gebze
# 3      pari   NaN  4000.0  istanbul   kaynarca
# 4  abdullah  45.0  5000.0  istanbul     pendik

# %%
veri["maas_yuzde_20_zamli"] = veri["maas"] + 20*veri["maas"]/100
veri
# Out:
#        isim   yas    maas     sehir       ilce  maas_yuzde_20_zamli
# 0     damla  24.0  1200.0  istanbul  kuzguncuk               1440.0
# 1      arda  32.0  2400.0  istanbul        NaN               2880.0
# 2    rukiye  27.0  3600.0  istanbul      gebze               4320.0
# 3      pari   NaN  4800.0  istanbul   kaynarca               5760.0
# 4  abdullah  45.0  6000.0  istanbul     pendik               7200.0

# %% [markdown]
# *Belirli satırları seçmek:*
#
# ```
# print(df.iloc[0:2]) # Index'e göre seçim
# print(df.loc[df['yas'] > 25]) # Koşullu seçim
# ```

# %%
print(veri.loc[:,"yas"])
print("---------------")
print(veri.loc[1:3,["isim","maas"]])
print("---------------")
print(veri.loc[1:3,"isim":"maas"])
print("---------------")
print(veri.iloc[0:2,0])
# Out:
# 0    24.0
# 1    32.0
# 2    27.0
# 3     NaN
# 4    45.0
# Name: yas, dtype: float64
# ---------------
#      isim    maas
# 1    arda  2400.0
# 2  rukiye  3600.0
# 3    pari  4800.0
# ---------------
#      isim   yas    maas
# 1    arda  32.0  2400.0
# 2  rukiye  27.0  3600.0
# 3    pari   NaN  4800.0
# ---------------
# 0    damla
# 1     arda
# Name: isim, dtype: object

# %%
print(veri.iloc[0:2,0])
print("---------------")
print(veri.iloc[[0,2],[0,2]]) #index
print("---------------")
print(veri.iloc[0:2,0:2]) #aralık
# Out:
# 0    damla
# 1     arda
# Name: isim, dtype: object
# ---------------
#      isim    maas
# 0   damla  1200.0
# 2  rukiye  3600.0
# ---------------
#     isim   yas
# 0  damla  24.0
# 1   arda  32.0

# %%
veri["maas2"] = veri["maas"] + 10
veri
# Out:
#        isim   yas    maas     sehir       ilce  maas_yuzde_20_zamli   maas2
# 0     damla  24.0  1200.0  istanbul  kuzguncuk               1440.0  1210.0
# 1      arda  32.0  2400.0  istanbul        NaN               2880.0  2410.0
# 2    rukiye  27.0  3600.0  istanbul      gebze               4320.0  3610.0
# 3      pari   NaN  4800.0  istanbul   kaynarca               5760.0  4810.0
# 4  abdullah  45.0  6000.0  istanbul     pendik               7200.0  6010.0

# %%
cols = veri.columns.tolist()  #convert columns to list
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'ilce', 'maas_yuzde_20_zamli', 'maas2']

# %%
maas2_index = cols.index('maas2')
maas2_index
# Out:
# 6

# %%
maas2_index=veri.columns.get_loc("maas2")
maas2_index
# Out:
# 6

# %%
maas2_index=veri.columns.tolist().index("maas2")
maas2_index
# Out:
# 6

# %%
#cols.remove('maas2')
veri.columns #burda durmaya devam eder
cols #burdan silmiş oluyoruz
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'ilce', 'maas_yuzde_20_zamli']

# %%
cols.insert(1,'maas2') #maas2 yi yas'tan sonra ekleyin (index 2)
cols
# Out:
# ['isim', 'maas2', 'yas', 'maas', 'sehir', 'ilce', 'maas_yuzde_20_zamli']

# %%
veri=veri[cols] #colsta yaptıgımz değişiklikleri veriye eklemek için
veri
# Out:
#        isim   maas2   yas    maas     sehir       ilce  maas_yuzde_20_zamli
# 0     damla  1210.0  24.0  1200.0  istanbul  kuzguncuk               1440.0
# 1      arda  2410.0  32.0  2400.0  istanbul        NaN               2880.0
# 2    rukiye  3610.0  27.0  3600.0  istanbul      gebze               4320.0
# 3      pari  4810.0   NaN  4800.0  istanbul   kaynarca               5760.0
# 4  abdullah  6010.0  45.0  6000.0  istanbul     pendik               7200.0

# %% [markdown]
# **alıştırma**

# %%
dict = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}
veri=pd.DataFrame(dict)
veri
"""
1) murat	33
2) 45 110
   66 220
3) veli 45
"""
# Out:
#     isim  yas   maas
# 0    ali   15  100.0
# 1   veli   16  150.0
# 2  kenan   17  240.0
# 3  murat   33  350.0
# 4   ayse   45  110.0
# 5  hilal   66  220.0

# %%
#iloc ile
veri.iloc[[3],[0,1]]
veri.iloc[4:6,1:3]
veri.iloc[[1],[]]
#iloc ile
print("1.soru-----------------------------------------------------------")
print(veri.iloc[3, 0:2]) # 1.sorunun cevabı.
print("2.soru-----------------------------------------------------------")
print(veri.iloc[4:, 1:3]) # 2.sorunun cevabı.
print("3.soru-----------------------------------------------------------")
print(veri.iloc[1, 0], veri.iloc[4, 1]) # 3.Sorunun cevabı
#loc ile
print("1.soru-----------------------------------------------------------")
print(veri.loc[3, "isim":"yas"]) # 1.sorunun cevabı.
print("2.soru-----------------------------------------------------------")
print(veri.loc[4:, "yas":"maas"]) # 2.sorunun cevabı.
print("3.soru-----------------------------------------------------------")
print(veri.loc[1, "isim"], veri.loc[4, "yas"]) # 3.Sorunun cevabı
# Out:
# 1.soru-----------------------------------------------------------
# isim    murat
# yas        33
# Name: 3, dtype: object
# 2.soru-----------------------------------------------------------
#    yas   maas
# 4   45  110.0
# 5   66  220.0
# 3.soru-----------------------------------------------------------
# veli 45
# 1.soru-----------------------------------------------------------
# isim    murat
# yas        33
# Name: 3, dtype: object
# 2.soru-----------------------------------------------------------
#    yas   maas
# 4   45  110.0
# 5   66  220.0
# 3.soru-----------------------------------------------------------
# veli 45

# %% [markdown]
# **filtreleme**

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
filtre1=veri["yas"]>15
filtre1
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# Name: yas, dtype: bool

# %%
filtrelenmis_veri=veri[filtre1] #filtreyi veriye uygulamak için
filtrelenmis_veri
# Out:
#     isim  yas    sehir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
filtre2=veri["sehir"]=="ankara"
veri[filtre2]
# Out:
#     isim  yas   sehir
# 1   veli   16  ankara
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
veri[filtre1&filtre2]
# Out:
#     isim  yas   sehir
# 1   veli   16  ankara
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
filtre3=veri["isim"]=="ali"
veri[filtre3]
# Out:
#   isim  yas  sehir
# 0  ali   15  izmir

# %%
np.bitwise_and(veri["yas"]>15,veri["sehir"]=="ankara")
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
veri[veri["yas"]>15]
# Out:
#     isim  yas    sehir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# Name: yas, dtype: bool

# %%
filtered_veri = veri.loc[(veri["sehir"] == "ankara") & (veri["yas"] > 22)]
print(veri[(veri["sehir"] == "ankara") & (veri["yas"] > 22)])
print("--------------------------------------------------------")
print(filtered_veri)
# Out:
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara
# --------------------------------------------------------
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %% [markdown]
# **alıştırma**

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
"""
1) yeni sutun: maas sutunu ekle
2) yeni sutun: yas/maas orani sutunu ekle
3) yas/maas sutunu icin ortalamayi print ettir
4) ankarada yasayanlarin ortalama yasini bul
5) ankarada yasayanlarin icinden en yuksek maas alani bul
"""

# %%
veri["maas"]=[1000,2000,3000,4000,5000,6000]
veri
# Out:
#     isim  yas    sehir  maas
# 0    ali   15    izmir  1000
# 1   veli   16   ankara  2000
# 2  kenan   17    konya  3000
# 3  murat   33   ankara  4000
# 4   ayse   45   ankara  5000
# 5  hilal   66  antalya  6000

# %%
veri["yas/maas"]=veri['yas']/veri['maas']
veri
# Out:
# <bound method DataFrame.mean of     isim  yas    sehir  maas  yas/maas
# 0    ali   15    izmir  1000  0.015000
# 1   veli   16   ankara  2000  0.008000
# 2  kenan   17    konya  3000  0.005667
# 3  murat   33   ankara  4000  0.008250
# 4   ayse   45   ankara  5000  0.009000
# 5  hilal   66  antalya  6000  0.011000>

# %%
np.mean(veri["yas/maas"])
# Out:
# 0.009486111111111112

# %%
veri["ulke"] = ["turkiye"]*len(veri)
veri
# Out:
#     isim  yas    sehir  maas  yas/maas     ulke
# 0    ali   15    izmir  1000  0.015000  turkiye
# 1   veli   16   ankara  2000  0.008000  turkiye
# 2  kenan   17    konya  3000  0.005667  turkiye
# 3  murat   33   ankara  4000  0.008250  turkiye
# 4   ayse   45   ankara  5000  0.009000  turkiye
# 5  hilal   66  antalya  6000  0.011000  turkiye

# %%
ankarada_yasayanlar=veri[veri["sehir"]=="ankara"]
print(ankarada_yasayanlar)
ankarada_yasayanlar["yas"].mean() #ankarada yaşayanların yaşlarının ortalaması
np.mean(ankarada_yasayanlar["yas"])
# Out:
#     isim  yas   sehir  maas  yas/maas     ulke
# 1   veli   16  ankara  2000   0.00800  turkiye
# 3  murat   33  ankara  4000   0.00825  turkiye
# 4   ayse   45  ankara  5000   0.00900  turkiye
# 31.333333333333332

# %%
ankarada_yasayanlar["maas"].max() #ankarada yaşayanların en yüksek maaşı
np.max(ankarada_yasayanlar["maas"])
# Out:
# 5000

# %% [markdown]
# *Bu kod satırı, Pandas DataFrame'i olan ankarada_yasayanlar üzerinde işlem yapar ve indeksini sıfırlar.*
#
# 1.   drop=True:
#
# Bu argüman, eski indeksi DataFrame'den kaldırır ve yeni bir sıralı indeks (0'dan başlayarak) oluşturur. Eski indeksi yeni bir sütun olarak saklamak istemiyorsanız, bu argümanı True olarak ayarlamalısınız.
#
# 2. inplace=True:
#
# Bu argüman, DataFrame'i doğrudan değiştirir. Yani, yeni bir DataFrame oluşturmak yerine, mevcut ankarada_yasayanlar DataFrame'inin indeksi değiştirilir. inplace=True kullanmazsanız, reset_index() yöntemi yeni bir DataFrame döndürür ve orijinal DataFrame değişmeden kalır.*

# %%
#ankarada yaşayanların içinden en yüksek maaşı alanın adı
ankarada_yasayanlar.reset_index(drop=True,inplace=True)
ankarada_yasayanlar
# Out:
#     isim  yas   sehir  maas  yas/maas     ulke
# 0   veli   16  ankara  2000   0.00800  turkiye
# 1  murat   33  ankara  4000   0.00825  turkiye
# 2   ayse   45  ankara  5000   0.00900  turkiye

# %%
#for döngüsüyle ankarada yaşayanların içinden en yüksek maaşı alanın adı
maks_maas = 0
maks_isim = ""
for i in range(len(ankarada_yasayanlar)):
    if ankarada_yasayanlar["maas"][i] > maks_maas:
        maks_maas = ankarada_yasayanlar["maas"][i]
        maks_isim = ankarada_yasayanlar["isim"][i]

print(maks_isim)
# Out:
# ayse

# %%
ankarada_yasayanlar.loc[ankarada_yasayanlar["maas"].idxmax(), "isim"]
print(ankarada_yasayanlar["maas"].idxmax())
# Out:
# 2

# %% [markdown]
# **List Comprehansion**: Liste Kavrama

# %%
import pandas as pd

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **alıştırma**

# %%
# insanlarin ortlama yasini bulalim
# bu yastan buyuk ve kucuk olanlari filtreleyelim
# buyuk olanlara yeni bir feature olusturarak buyu, kucuk olanlara ise kucuk yazalım

# %%
import numpy as np
# yas sutununu elde et
veri_yas = veri.yas
print(veri_yas)
# yas stununun ortalamasini bul
veri_yas_mean = np.mean(veri_yas)
print(f"veri_yas_mean: {veri_yas_mean}")
# for dongusu ile insanlarin yasini ortalamaya ile kiyasla
# eger yaslari kucuk ise bir listenini icerisine "kucuk" yazdir degilse(buyukse) "buyuk" yazdir
liste_yas_grubu = []
for i in range(len(veri_yas)):
  dummy_veri_yas = veri_yas[i]
  if veri_yas_mean > dummy_veri_yas:
    liste_yas_grubu.append("kucuk")
  else:
    liste_yas_grubu.append("buyuk")
print(liste_yas_grubu)
veri["yas_grubu"] = liste_yas_grubu
print(veri)
# Out:
# 0    15
# 1    16
# 2    17
# 3    33
# 4    45
# 5    66
# Name: yas, dtype: int64
# veri_yas_mean: 32.0
# ['kucuk', 'kucuk', 'kucuk', 'buyuk', 'buyuk', 'buyuk']
#     isim  yas    sehir yas_grubu
# 0    ali   15    izmir     kucuk
# 1   veli   16   ankara     kucuk
# 2  kenan   17    konya     kucuk
# 3  murat   33   ankara     buyuk
# 4   ayse   45   ankara     buyuk
# 5  hilal   66  antalya     buyuk

# %%
veri["yas_grubu2"]=["kucuk" if veri_yas_mean > veri_yas[i] else "buyuk" for i in range(len(veri_yas))]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2
# 0    ali   15    izmir     kucuk      kucuk
# 1   veli   16   ankara     kucuk      kucuk
# 2  kenan   17    konya     kucuk      kucuk
# 3  murat   33   ankara     buyuk      buyuk
# 4   ayse   45   ankara     buyuk      buyuk
# 5  hilal   66  antalya     buyuk      buyuk

# %%
veri["YAS_GRUBU2"] = [i.upper() for i in veri.yas_grubu2]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2 YAS_GRUBU2
# 0    ali   15    izmir     kucuk      kucuk      KUCUK
# 1   veli   16   ankara     kucuk      kucuk      KUCUK
# 2  kenan   17    konya     kucuk      kucuk      KUCUK
# 3  murat   33   ankara     buyuk      buyuk      BUYUK
# 4   ayse   45   ankara     buyuk      buyuk      BUYUK
# 5  hilal   66  antalya     buyuk      buyuk      BUYUK

# %%
veri.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# problem definition: tum satirlara bakalim eger ankarada yasayan varsa, yasini x 2 , else yas x 5
# new_yas sutun olusturalim
veri["new_yas"] = [veri.yas[i]*2 if veri.sehir[i]=="ankara" else veri.yas[i]*5 for i in range(len(veri))]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2 YAS_GRUBU2  new_yas
# 0    ali   15    izmir     kucuk      kucuk      KUCUK       75
# 1   veli   16   ankara     kucuk      kucuk      KUCUK       32
# 2  kenan   17    konya     kucuk      kucuk      KUCUK       85
# 3  murat   33   ankara     buyuk      buyuk      BUYUK       66
# 4   ayse   45   ankara     buyuk      buyuk      BUYUK       90
# 5  hilal   66  antalya     buyuk      buyuk      BUYUK      330

# %% [markdown]
# **apply metodu ile fonksiyonları veriye uygulama**

# %%
def yas10YilSonrasi(age):
  output = age + 10
  return output

# %%
veri["yas_10_yil_sonrasi"] = veri.yas.apply(yas10YilSonrasi)
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2 YAS_GRUBU2  new_yas  \
# 0    ali   15    izmir     kucuk      kucuk      KUCUK       75
# 1   veli   16   ankara     kucuk      kucuk      KUCUK       32
# 2  kenan   17    konya     kucuk      kucuk      KUCUK       85
# 3  murat   33   ankara     buyuk      buyuk      BUYUK       66
# 4   ayse   45   ankara     buyuk      buyuk      BUYUK       90
# 5  hilal   66  antalya     buyuk      buyuk      BUYUK      330
#
#    yas_10_yil_sonrasi
# 0                  25
# 1                  26
# 2                  27
# 3                  43
# 4                  55
# 5                  76

# %%
# [veri.yas[i]*2 if veri.sehir[i]=="ankara" else veri.yas[i]*5 for i in range(len(veri))]
def yasCarpim(df):
  if df.sehir == "ankara":
    return df.yas*2
  elif df.sehir == "izmir":
    return df.yas *3
  else:
    return df.yas*5

# %%
veri.apply(yasCarpim, axis = 1)
# Out:
# 0     45
# 1     32
# 2     85
# 3     66
# 4     90
# 5    330
# dtype: int64

# %%
# dataframe de bulunan insanlarin isimlerinin uzunlugu == 5 ise yeni yasi 2 ile varpalim
# eger isim uzunlugu == 4 ise 3 ile carpalim else 4 ile carpalim
def nameLength(df):
  if len(df.isim)==5:
    return df.yas*2
  elif len(df.isim)==4:
    return df.yas*3
  else:
    return df.yas*4
veri["new_age3"]=veri.apply(nameLength, axis=1)
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2 YAS_GRUBU2  new_yas  \
# 0    ali   15    izmir     kucuk      kucuk      KUCUK       75
# 1   veli   16   ankara     kucuk      kucuk      KUCUK       32
# 2  kenan   17    konya     kucuk      kucuk      KUCUK       85
# 3  murat   33   ankara     buyuk      buyuk      BUYUK       66
# 4   ayse   45   ankara     buyuk      buyuk      BUYUK       90
# 5  hilal   66  antalya     buyuk      buyuk      BUYUK      330
#
#    yas_10_yil_sonrasi  new_age3
# 0                  25        60
# 1                  26        48
# 2                  27        34
# 3                  43        66
# 4                  55       135
# 5                  76       132

# %%
def isimUzunlugu(kcy):
  if len(kcy.isim) == 5:
    return kcy.yas * 2
  elif len(kcy.isim) == 4:
    return kcy.yas * 3
  else: return kcy.yas * 4
veri["new_yas3"] = veri.apply(isimUzunlugu, axis = 1) # veriyi satir satir isim uzunlugna gonder
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2 YAS_GRUBU2  new_yas  \
# 0    ali   15    izmir     kucuk      kucuk      KUCUK       75
# 1   veli   16   ankara     kucuk      kucuk      KUCUK       32
# 2  kenan   17    konya     kucuk      kucuk      KUCUK       85
# 3  murat   33   ankara     buyuk      buyuk      BUYUK       66
# 4   ayse   45   ankara     buyuk      buyuk      BUYUK       90
# 5  hilal   66  antalya     buyuk      buyuk      BUYUK      330
#
#    yas_10_yil_sonrasi  new_age3  new_yas3
# 0                  25        60        60
# 1                  26        48        48
# 2                  27        34        34
# 3                  43        66        66
# 4                  55       135       135
# 5                  76       132       132

# %% [markdown]
# **birleştirme**

# %%
import pandas as pd
sozluk1 = {"isim": ["ali", "veli"],
           "yas": [15, 16]}
veri1 = pd.DataFrame(sozluk1)
veri1
# Out:
#    isim  yas
# 0   ali   15
# 1  veli   16

# %%
sozluk2 = {"isim": ["murat", "ayse"],
           "yas": [32, 33]}
veri2 = pd.DataFrame(sozluk2)
veri2
# Out:
#     isim  yas
# 0  murat   32
# 1   ayse   33

# %%
# concat
veri_dikey = pd.concat([veri1, veri2], axis = 0)
veri_dikey
# Out:
#     isim  yas
# 0    ali   15
# 1   veli   16
# 0  murat   32
# 1   ayse   33

# %%
# concat
veri_yatay = pd.concat([veri1, veri2], axis = 1)
veri_yatay
# Out:
#    isim  yas   isim  yas
# 0   ali   15  murat   32
# 1  veli   16   ayse   33

# %%
sozluk1 = {"isim": ["ali", "veli"],
           "yas": [15, 16]}
veri1 = pd.DataFrame(sozluk1)
print(veri1)
sozluk3 = {"sehir": ["ankara", "istanbul"],
           "yas": [22, 23]}
veri3 = pd.DataFrame(sozluk3)
veri3
# Out:
#    isim  yas
# 0   ali   15
# 1  veli   16
#       sehir  yas
# 0    ankara   22
# 1  istanbul   23

# %%
veri_yatay = pd.concat([veri1, veri3], axis = 1)
veri_yatay
# Out:
#    isim  yas     sehir  yas
# 0   ali   15    ankara   22
# 1  veli   16  istanbul   23

# %%
veri_dikey = pd.concat([veri1, veri3], axis = 0, ignore_index=True)
#veri_dikey.reset_index(drop=True, inplace=True)
veri_dikey
# Out:
#    isim  yas     sehir
# 0   ali   15       NaN
# 1  veli   16       NaN
# 2   NaN   22    ankara
# 3   NaN   23  istanbul
